# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from Project.IsingModel.Ising1 import IsingGrid

# %%
ising = IsingGrid(n=256, a=0.5)
ising.randomflips(0.7)
ising.savegrid('testbefore')
elist = ising.samplegibbs()
ising.savegrid('testafter')

# %%
plt.subplot()
plt.plot(elist)
plt.autoscale(enable=True, axis='both', tight=None)
plt.show()

# %%
finalenergylist = []
numbiterlist =[]
for a in np.linspace(0.02, 2, 10):
    ising = IsingGrid(n=256, a=a)
    ising.randomflips(.3)
    elist = ising.samplegibbs()
    numbiterlist.append(len(elist))
    finalenergylist.append(int(elist[-1]/a))
    ising.savegrid('im' + str(int(100*a)).zfill(3))

print(numbiterlist)
print(finalenergylist)
# Out:
# [16, 8, 8, 6, 3, 5, 6, 5, 4, 6, 4, 7, 8, 5, 4, 5, 4, 5, 7, 16, 15, 14, 12, 11, 10, 23, 13, 8, 11, 9, 14, 18, 4, 6, 7, 44, 32, 8, 8, 11, 36, 19, 9, 25, 29, 47, 32, 63, 26, 20, 24, 37, 17, 67, 47, 78, 32, 54, 26, 61, 101, 25, 49, 34, 93, 62, 53, 22, 101, 60, 46, 61, 101, 22, 101, 68, 96, 101, 51, 39, 79, 79, 101, 101, 70, 101, 101, 101, 101, 101, 58, 101, 101, 101, 101, 36, 81, 101, 56, 54]
# [64787, 63957, 63188, 62870, 62068, 61223, 60521, 59911, 59332, 58765, 58042, 57616, 56748, 55907, 55127, 54452, 53533, 52923, 52135, 51352, 50400, 49573, 48668, 48371, 47328, 46374, 45551, 44204, 43703, 42081, 41537, 40644, 37628, 36338, 35407, 35100, 34116, 31368, 29480, 27923, 26239, 24134, 23200, 19759, 17369, 15089, 14008, 11149, 11559, 10627, 8900, 7486, 8233, 5829, 5292, 4847, 4443, 3892, 3853, 3024, 2833, 3011, 2490, 2213, 1901, 1699, 1648, 1874, 1444, 1364, 1176, 1027, 968, 1202, 854, 710, 687, 603, 537, 579, 512, 437, 373, 398, 310, 271, 291, 310, 296, 205, 151, 208, 168, 208, 168, 136, 136, 121, 114, 98]
# [4, 7, 11, 21, 28, 31, 101, 55, 101, 83]
# [64833, 57144, 48705, 37736, 17470, 5024, 1692, 581, 262, 89]
# [6, 10, 7, 22, 15, 72, 18, 101, 71, 101]
# [64442, 57222, 48936, 37828, 18600, 4775, 2282, 642, 276, 157]
